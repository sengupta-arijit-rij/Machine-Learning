# %% [markdown]
# <a href="https://colab.research.google.com/github/sengupta-arijit-rij/Machine-Learning/blob/main/PythonForDataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello world once again')
# Out:
# hello world once again

# %%
import numpy as np
import matplotlib.pyplot as plt

distance=[12,30,60,80,40,20,30]
print(type(distance))

my_Distance=np.array([12,30,60,80,40,20,30])
print(type(my_Distance))
my_Time=np.array([30,60,90,70,15,10,20])

my_Speed=np.divide(my_Distance,my_Time)
print(my_Speed)
print(np.size(my_Speed))

plt.plot(my_Distance,my_Time,2)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# [0.4        0.5        0.66666667 1.14285714 2.66666667 2.
#  1.5       ]
# 7
# ...

# %%
ListOfLists=[[1,2,3,4],[4,5,6,7],[7,8,9,10]]
ListOfLists
ConvertToArray=np.array(ListOfLists)
ConvertToArray

np.size(ConvertToArray)
np.shape(ConvertToArray)
# Out:
# (3, 4)

# %%
import pandas as pd

# read dataset

flag_data_url='https://archive.ics.uci.edu/ml/machine-learning-databases/flags/flag.data'
column_headers=['name','landmass','zone','area','population','language','religion','bars','stripes','colours','red','green','blue','gold',
'white','black','orange','mainhue','circles','crosses','saltires','quarters','sunstars','crescent','triangle','icon',
'animate','text','topleft','botright']
flag_dataset=pd.read_csv(flag_data_url,names=column_headers)

# flag_dataset dimensions
flag_dataset.shape

# view top 5 rows of dataset
flag_dataset.head()
# Out:
#              name  landmass  zone  area  population  language  religion  bars  \
# 0     Afghanistan         5     1   648          16        10         2     0
# 1         Albania         3     1    29           3         6         6     0
# 2         Algeria         4     1  2388          20         8         2     2
# 3  American-Samoa         6     3     0           0         1         1     0
# 4         Andorra         3     1     0           0         6         0     3
#
#    stripes  colours  ...  saltires  quarters  sunstars  crescent  triangle  \
# 0        3        5  ...         0         0         1         0         0
# 1        0        3  ...         0         0         1         0         0
# 2        0        3  ...         0         0         1         1         0
# 3        0        5  ...         0         0         0         0         1
# 4        0        3  ...         0         0         0         0         0
#
#    icon  animate text  topleft  botright
# ...

# %%
# view last 5 rows of dataset
flag_dataset.tail()
# Out:
#               name  landmass  zone  area  population  language  religion  \
# 189  Western-Samoa         6     3     3           0         1         1
# 190     Yugoslavia         3     1   256          22         6         6
# 191          Zaire         4     2   905          28        10         5
# 192         Zambia         4     2   753           6        10         5
# 193       Zimbabwe         4     2   391           8        10         5
#
#      bars  stripes  colours  ...  saltires  quarters  sunstars  crescent  \
# 189     0        0        3  ...         0         1         5         0
# 190     0        3        4  ...         0         0         1         0
# 191     0        0        4  ...         0         0         0         0
# 192     3        0        4  ...         0         0         0         0
# 193     0        7        5  ...         0         0         1         0
#
#      triangle  icon  animate text  topleft  botright
# ...

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-19b3b326-1486-43a2-9736-9cd8fe44849c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-19b3b326-1486-43a2-9736-9cd8fe44849c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving disneymarathon2020.csv to disneymarathon2020.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# clm_headers=['gender','age','place','group','netTime','minutes','mph']
import pandas as pd
disney=pd.read_csv('disneymarathon2020.csv')
disney.head()
# Out:
#   gender  age  place    group  netTime     minutes        mph
# 0      M   30      1  M30-34   2:22:19  142.316667  11.053695
# 1      M   26      2  M25-29   2:27:02  147.033333  10.699105
# 2      M   32      3  M30-34   2:27:28  147.466667  10.667665
# 3      M   35      4  M35-39   2:39:20  159.350000   9.872137
# 4      M   26      5  M25-29   2:44:09  164.166667   9.582487

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14106 entries, 0 to 14105
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gender   14106 non-null  object
#  1   age      14106 non-null  int64
#  2   place    14106 non-null  int64
#  3   group    14106 non-null  object
#  4   netTime  14106 non-null  object
#  5   minutes  14106 non-null  float64
#  6   mph      14106 non-null  float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 771.5+ KB

# %%
disney.dtypes
# Out:
# gender      object
# age          int64
# place        int64
# group       object
# netTime     object
# minutes    float64
# mph        float64
# dtype: object

# %%
disney.describe(include='number')
# Out:
#                 age         place       minutes           mph
# count  14106.000000  14106.000000  14106.000000  14106.000000
# mean      39.946902   7053.500000    363.727572      4.478961
# std       10.826456   4072.195784     61.609263      0.932945
# min       18.000000      1.000000    142.316667      3.532995
# 25%       32.000000   3527.250000    320.333333      3.774330
# 50%       39.000000   7053.500000    378.533333      4.155843
# 75%       47.000000  10579.750000    416.795833      4.910900
# max       84.000000  14106.000000    445.266667     11.053695

# %%
disney.describe(include='all')
# Out:
#        gender           age         place    group  netTime       minutes  \
# count   14106  14106.000000  14106.000000    14106    14106  14106.000000
# unique      2           NaN           NaN       26     7693           NaN
# top         F           NaN           NaN  F35-39   6:48:10           NaN
# freq     7529           NaN           NaN     1374        8           NaN
# mean      NaN     39.946902   7053.500000      NaN      NaN    363.727572
# std       NaN     10.826456   4072.195784      NaN      NaN     61.609263
# min       NaN     18.000000      1.000000      NaN      NaN    142.316667
# 25%       NaN     32.000000   3527.250000      NaN      NaN    320.333333
# 50%       NaN     39.000000   7053.500000      NaN      NaN    378.533333
# 75%       NaN     47.000000  10579.750000      NaN      NaN    416.795833
# max       NaN     84.000000  14106.000000      NaN      NaN    445.266667
#
#                  mph
# count   14106.000000
# unique           NaN
# ...

# %%
disney.place
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 14101    14102
# 14102    14103
# 14103    14104
# 14104    14105
# 14105    14106
# Name: place, Length: 14106, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt


disney.sort_values(by=['age'])
gender_array=np.array(disney.gender)
print(gender_array)
age_array=np.array(disney.age)
print(age_array)
plt.bar(gender_array,age_array)
plt.xlabel('Gender')
plt.ylabel('Age')
# Out:
# ['M' 'M' 'M' ... 'M' 'M' 'M']
# [30 26 32 ... 39 52 46]
# Text(0, 0.5, 'Age')

# %%
minutes_array=np.array(disney.minutes)
plt.scatter(minutes_array,age_array)

# %%
#Actual group values
GroupArray=np.array(disney['group'].value_counts())
GroupArray
GrpValArray=np.array(disney.group.unique)
GrpValArray.shape
# plt.bar(GrpValArray,GroupArray)
# Out:
# ()

# %%
# Percentile group values
disney['group'].value_counts(normalize=True)
# Out:
# F35-39     0.097405
# F30-34     0.086559
# F25-29     0.082589
# F40-44     0.080250
# M40-44     0.078690
# M35-39     0.078406
# M30-34     0.068978
# F45-49     0.065433
# M45-49     0.060613
# M50-54     0.051184
# M25-29     0.044166
# F50-54     0.040905
# F18-24     0.037998
# M55-59     0.030058
# F55-59     0.025946
# M18-24     0.021835
# M60-64     0.020488
# F60-64     0.011626
# M65-69     0.008011
# F65-69     0.003970
# M70-74     0.003048
# F70-74     0.000922
# M75-79     0.000709
# M80-99     0.000071
# F75-79     0.000071
# F80-99     0.000071
# Name: group, dtype: float64
