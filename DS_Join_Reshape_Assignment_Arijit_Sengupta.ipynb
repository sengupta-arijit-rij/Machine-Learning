# %% [markdown]
# <a href="https://colab.research.google.com/github/sengupta-arijit-rij/Machine-Learning/blob/WorkingBranch/DS_Join_Reshape_Assignment_Arijit_Sengupta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import pandas as pd

# %% [markdown]
# Task 1:

# %%
# Load tables
data_url1 = 'https://raw.githubusercontent.com/pixeltests/datasets/main/product_names_sm.csv'
product_names=pd.read_csv(data_url1)
product_names.head()
# Out:
#    product_id                                    product_name  aisle_id  \
# 0       45676  Oil Free Acne Stress Control Power Clear Scrub        73
# 1       35408                      Soymilk Vanilla Value Size        91
# 2       37442                                       Vegan Egg        86
# 3       41599                 Organic Echinacea Herb Capsules        47
# 4       21994                      Premium Saline Nasal Spray        11
#
#    department_id
# 0             11
# 1             16
# 2             16
# 3             11
# 4             11

# %% [markdown]
# Task 2:

# %%
# Load order_products_prior table
data_url2 = 'https://raw.githubusercontent.com/pixeltests/datasets/main/order_products_prior_sm.csv'
data_url3 = 'https://raw.githubusercontent.com/pixeltests/datasets/main/order_products_train_sm.csv'

order_products_prior=pd.read_csv(data_url2)
order_products_prior.info()
order_products_prior.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           25000 non-null  int64
#  1   product_id         25000 non-null  int64
#  2   add_to_cart_order  25000 non-null  int64
#  3   reordered          25000 non-null  int64
# dtypes: int64(4)
# memory usage: 781.4 KB
#    order_id  product_id  add_to_cart_order  reordered
# 0   1696715       34969                 11          0
# 1   2077308       16641                 16          0
# 2    303457       46881                  6          0
# 3    514151       31766                  9          0
# 4   2099209        7908                 10          1

# %%
# Load order_products_train table
order_products_train=pd.read_csv(data_url3)
order_products_train.info()
order_products_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           25000 non-null  int64
#  1   product_id         25000 non-null  int64
#  2   add_to_cart_order  25000 non-null  int64
#  3   reordered          25000 non-null  int64
# dtypes: int64(4)
# memory usage: 781.4 KB
#    order_id  product_id  add_to_cart_order  reordered
# 0   3178234       22620                  2          0
# 1   2319083       27156                 14          0
# 2   1951854        5818                  9          1
# 3   1615787       40198                 13          0
# 4   1666094       14491                 13          0

# %%
# Concatenate order_products_prior and order_products_train into one DataFrame called order_products.
order_products=pd.concat([order_products_prior,order_products_train])
order_products.info()
order_products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 24999
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           50000 non-null  int64
#  1   product_id         50000 non-null  int64
#  2   add_to_cart_order  50000 non-null  int64
#  3   reordered          50000 non-null  int64
# dtypes: int64(4)
# memory usage: 1.9 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0   1696715       34969                 11          0
# 1   2077308       16641                 16          0
# 2    303457       46881                  6          0
# 3    514151       31766                  9          0
# 4   2099209        7908                 10          1

# %% [markdown]
# Task 3:

# %%
# Create a list of top 5 products
five_products=["Bag of Organic Bananas", "Organic Baby Spinach", "Organic Avocado", "Large Lemon", "Limes"]
five_products
# Out:
# ['Bag of Organic Bananas',
#  'Organic Baby Spinach',
#  'Organic Avocado',
#  'Large Lemon',
#  'Limes']

# %% [markdown]
# Task 4:

# %%
# Convert five_products to a dataframe five
five=pd.DataFrame(data=five_products,columns=['product_name'])
five
# Out:
#              product_name
# 0  Bag of Organic Bananas
# 1    Organic Baby Spinach
# 2         Organic Avocado
# 3             Large Lemon
# 4                   Limes

# %%
# Create subset top_products merging Five and product_names
top_products=pd.merge(five,product_names,how="left",on="product_name")
top_products
# Out:
#              product_name  product_id  aisle_id  department_id
# 0  Bag of Organic Bananas       13176        24              4
# 1    Organic Baby Spinach       21903       123              4
# 2         Organic Avocado       47766        24              4
# 3             Large Lemon       47626        24              4
# 4                   Limes       26209        24              4

# %% [markdown]
# Task 5:

# %%
# Merge order_products and top_products and name the resulting DataFrame final
final=pd.merge(order_products,top_products,how="inner",on="product_id")
final.head(20)
# Out:
#     order_id  product_id  add_to_cart_order  reordered product_name  aisle_id  \
# 0    2469765       26209                 11          0        Limes        24
# 1    2322104       26209                  6          1        Limes        24
# 2    1297655       26209                 15          1        Limes        24
# 3    1397335       26209                  8          1        Limes        24
# 4     651387       26209                  2          1        Limes        24
# 5    1338110       26209                  5          1        Limes        24
# 6    2587073       26209                  2          1        Limes        24
# 7      25158       26209                  9          1        Limes        24
# 8    2652386       26209                 11          1        Limes        24
# 9     440430       26209                  5          1        Limes        24
# 10   1080877       26209                  9          1        Limes        24
# 11    105005       26209                  3          1        Limes        24
# 12    868591       26209                 14          1        Limes        24
# 13    842603       26209                  2          0        Limes        24
# 14   1765563       26209                 15          0        Limes        24
# 15   1730767       26209                 37          1        Limes        24
# 16    672740       26209                  6          1        Limes        24
# 17    459187       26209                  8          1        Limes        24
# 18   2847056       26209                 19          1        Limes        24
# 19    620885       26209                 10          0        Limes        24
#
#     department_id
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# 5               4
# 6               4
# 7               4
# 8               4
# 9               4
# 10              4
# 11              4
# 12              4
# 13              4
# 14              4
# 15              4
# 16              4
# 17              4
# 18              4
# 19              4

# %% [markdown]
# Task 6:

# %%
# Calculate the number of times each product was ordered using value_counts(). Name the result food_frequency.
food_frequency=final['product_id'].value_counts()
food_frequency
# Out:
# 13176    561
# 21903    360
# 47626    283
# 47766    269
# 26209    197
# Name: product_id, dtype: int64

# %% [markdown]
# Task 7:

# %%
# Imported orders_sm.csv as the DataFrame orders.
data_url4 = 'https://raw.githubusercontent.com/pixeltests/datasets/main/orders_sm.csv'
orders = pd.read_csv(data_url4)
orders.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    209450     4647    prior            36          1                 16
# 1   2381956   117152    prior            14          0                 12
# 2   2294641   123531    prior            50          0                 13
# 3   2674353   167358    prior            14          1                 11
# 4   1776425    14814    prior            13          1                 19
#
#    days_since_prior_order
# 0                     8.0
# 1                    15.0
# 2                    14.0
# 3                     8.0
# 4                     4.0

# %%
from re import A
# Merged orders and final into a DataFrame called final_times that only includes the top five foods.
final_time = pd.merge(orders, final, on='order_id', how='right')
final_time.describe(include='all')
# Out:
#             order_id        user_id eval_set  order_number  order_dow  \
# count   1.670000e+03      17.000000       17     17.000000  17.000000
# unique           NaN            NaN        2           NaN        NaN
# top              NaN            NaN    train           NaN        NaN
# freq             NaN            NaN       10           NaN        NaN
# mean    1.687414e+06   79888.352941      NaN     17.470588   3.705882
# std     9.948345e+05   51373.102145      NaN     23.425727   2.391775
# min     1.128600e+04   14325.000000      NaN      2.000000   0.000000
# 25%     8.052055e+05   43656.000000      NaN      5.000000   2.000000
# 50%     1.648202e+06   67040.000000      NaN      8.000000   3.000000
# 75%     2.576474e+06  105856.000000      NaN     20.000000   6.000000
# max     3.416878e+06  203800.000000      NaN     98.000000   6.000000
#
#         order_hour_of_day  days_since_prior_order    product_id  \
# count           17.000000               17.000000   1670.000000
# unique                NaN                     NaN           NaN
# top                   NaN                     NaN           NaN
# freq                  NaN                     NaN           NaN
# mean            14.176471               13.823529  28004.311976
# std              4.019255                9.837653  14510.123347
# min              8.000000                2.000000  13176.000000
# 25%             11.000000                7.000000  13176.000000
# 50%             15.000000               10.000000  21903.000000
# 75%             18.000000               14.000000  47626.000000
# max             20.000000               30.000000  47766.000000
#
#         add_to_cart_order    reordered            product_name     aisle_id  \
# count         1670.000000  1670.000000                    1670  1670.000000
# unique                NaN          NaN                       5          NaN
# top                   NaN          NaN  Bag of Organic Bananas          NaN
# freq                  NaN          NaN                     561          NaN
# mean             6.599401     0.786228                     NaN    45.341317
# std              5.771825     0.410091                     NaN    40.722618
# min              1.000000     0.000000                     NaN    24.000000
# 25%              2.000000     1.000000                     NaN    24.000000
# 50%              5.000000     1.000000                     NaN    24.000000
# 75%              9.000000     1.000000                     NaN    24.000000
# max             40.000000     1.000000                     NaN   123.000000
#
#         department_id
# count          1670.0
# unique            NaN
# top               NaN
# freq              NaN
# mean              4.0
# std               0.0
# min               4.0
# 25%               4.0
# 50%               4.0
# 75%               4.0
# max               4.0

# %%
mean_hours=final_time.groupby('product_name')['order_hour_of_day'].mean()
mean_hours
# Out:
# product_name
# Bag of Organic Bananas    13.200000
# Large Lemon               16.000000
# Limes                     10.333333
# Organic Avocado           17.500000
# Organic Baby Spinach      14.500000
# Name: order_hour_of_day, dtype: float64

# %% [markdown]
# Task 8:

# %%
# Find the mean order time for "Limes" and assign it to the variable time_limes.
# Find the mean order time for "Organic Baby Spinach" and assign it to the variable time_spinach
time_limes=mean_hours['Limes']
time_spinach=mean_hours['Organic Baby Spinach']

print('mean order time for Limes is {} and mean order time for Organic Baby Spinach is {}'.format(time_limes,time_spinach))
# Out:
# mean order time for Limes is 10.333333333333334 and mean order time for Organic Baby Spinach is 14.5
